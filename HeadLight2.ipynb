# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# Out:
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-rpxni6u5
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-rpxni6u5
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=375643 sha256=0351b9947a737f51ab8620ae3901c1616579c5a3b0b3e2bde7e5d964b3371c53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zdtk6gdu/wheels/39/61/b4/480fbddb4d3d6bc34083e7397bc6f5d1381f79acc68e9f3511
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.7
#     Uninstalling pycocotools-2.0.7:
#       Successfully uninstalled pycocotools-2.0.7
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data for demonstration
np.random.seed(0)
num_samples = 1000

# Assume three features: area of damage, severity of damage, and labor hours
area_of_damage = np.random.uniform(10, 100, num_samples)  # Random area in square inches
severity_of_damage = np.random.uniform(1, 10, num_samples)  # Random severity level
labor_hours = np.random.uniform(1, 10, num_samples)  # Random labor hours required for repair

# Generate synthetic repair costs based on the features with some noise
repair_cost = 100 * area_of_damage + 50 * severity_of_damage + 20 * labor_hours + np.random.normal(0, 100, num_samples)

# Stack features into a feature matrix
X = np.column_stack((area_of_damage, severity_of_damage, labor_hours))

# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, repair_cost, test_size=0.2, random_state=42)

# Train a linear regression model
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)

# Predict repair costs for test data
predicted_costs = reg_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predicted_costs)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 8611.48961664828

# %%
import tensorflow as tf
import os

data_dir = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/not damaged"
subdirs = os.listdir(data_dir)

for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    if os.path.isdir(subdir_path):
        count = len(os.listdir(subdir_path))
        print("Subfolder:", subdir, "Image count:", count)
# Out:
# Subfolder: front buffer Image count: 92
# Subfolder: hood Image count: 67
# Subfolder: headlight Image count: 88

# %%
import tensorflow as tf
import os

data_dir = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/damged"
subdirs = os.listdir(data_dir)

for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    if os.path.isdir(subdir_path):
        count = len(os.listdir(subdir_path))
        print("Subfolder:", subdir, "Image count:", count)
# Out:
# Subfolder: Minor Damages Image count: 3
# Subfolder: Moderate Damages Image count: 3
# Subfolder: Severe Damages Image count: 3

# %%
import os
from PIL import Image

# set paths
input_folder = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/not damaged/headlight"
output_folder = "/content/drive/MyDrive/RenamedDataset3/Renamed/not damaged/headlight"

# create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# iterate through all files in input folder
for i, filename in enumerate(os.listdir(input_folder)):
    # only process image files
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        # open the image file
        with Image.open(os.path.join(input_folder, filename)) as img:
            # convert to PNG format
            img = img.convert("RGB")
            # save with new filename and extension
            new_filename = "Headlight_"+ str(i+1) + ".png"
            img.save(os.path.join(output_folder, new_filename))

# %%
import os

data_dir = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/damged"
subdirs = os.listdir(data_dir)

for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    if os.path.isdir(subdir_path):
        print("Subfolder:", subdir)
        for sub_subdir in os.listdir(subdir_path):
            sub_subdir_path = os.path.join(subdir_path, sub_subdir)
            if os.path.isdir(sub_subdir_path):
                count = len(os.listdir(sub_subdir_path))
                print("  Sub-subfolder:", sub_subdir, "Image count:", count)
# Out:
# Subfolder: Minor Damages
#   Sub-subfolder: frontbuffer (minor) Image count: 85
#   Sub-subfolder: hood(minor) Image count: 76
#   Sub-subfolder: headlight (minor) Image count: 110
# Subfolder: Moderate Damages
#   Sub-subfolder: hood (moderate) Image count: 86
#   Sub-subfolder: headlight (moderate) Image count: 100
#   Sub-subfolder: frontbuffer (moderate) Image count: 70
# Subfolder: Severe Damages
#   Sub-subfolder: headlight (severe) Image count: 84
#   Sub-subfolder: frontbuffer (severe) Image count: 93
#   Sub-subfolder: hood (severe) Image count: 89

# %%
import os
from PIL import Image

# set paths
input_folder = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/damged/Minor Damages/headlight (minor)"
output_folder = "/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Minor Damages/headlight (minor)"

# create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# iterate through all files in input folder
for i, filename in enumerate(os.listdir(input_folder)):
    # only process image files
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        # open the image file
        with Image.open(os.path.join(input_folder, filename)) as img:
            # convert to PNG format
            img = img.convert("RGB")
            # save with new filename and extension
            new_filename = "Headlight(minor)_"+ str(i+1) + ".png"
            img.save(os.path.join(output_folder, new_filename))

# %%
import os
from PIL import Image

# set paths
input_folder = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/damged/Moderate Damages/headlight (moderate)"
output_folder = "/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Moderate Damages/headlight (moderate)"

# create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# iterate through all files in input folder
for i, filename in enumerate(os.listdir(input_folder)):
    # only process image files
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        # open the image file
        with Image.open(os.path.join(input_folder, filename)) as img:
            # convert to PNG format
            img = img.convert("RGB")
            # save with new filename and extension
            new_filename = "Headlight(moderate)_"+ str(i+1) + ".png"
            img.save(os.path.join(output_folder, new_filename))

# %%
import os
from PIL import Image

# set paths
input_folder = "/content/drive/MyDrive/Dataset2/CarDataset(self-composed)/damged/Severe Damages/headlight (severe)"
output_folder = "/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Severe Damages/headlight (severe)"

# create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# iterate through all files in input folder
for i, filename in enumerate(os.listdir(input_folder)):
    # only process image files
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        # open the image file
        with Image.open(os.path.join(input_folder, filename)) as img:
            # convert to PNG format
            img = img.convert("RGB")
            # save with new filename and extension
            new_filename = "Headlight(severe)_"+ str(i+1) + ".png"
            img.save(os.path.join(output_folder, new_filename))

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

# %%
pip install split-folders

# %%
# !pip install split-folders[full]

# %%
import splitfolders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.

splitfolders.ratio("/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Minor Damages",
                   output="/content/drive/MyDrive/RenamedDataset3/Renamed/test",seed=1330, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 3 files [00:00,  5.04 files/s]
# Copying files: 4 files [00:00,  4.63 files/s]
# Copying files: 7 files [00:00,  8.90 files/s]
# Copying files: 12 files [00:01, 15.49 files/s]
# Copying files: 16 files [00:01, 20.18 files/s]
# Copying files: 20 files [00:01, 24.29 files/s]
# Copying files: 24 files [00:01, 26.03 files/s]
# Copying files: 29 files [00:01, 30.33 files/s]
# Copying files: 33 files [00:01, 31.14 files/s]
# Copying files: 37 files [00:01, 30.24 files/s]
# Copying files: 41 files [00:01, 30.18 files/s]
# Copying files: 45 files [00:02, 29.94 files/s]
# Copying files: 49 files [00:02, 28.39 files/s]
# Copying files: 54 files [00:02, 31.50 files/s]
# Copying files: 58 files [00:02, 32.09 files/s]
# Copying files: 62 files [00:02, 28.53 files/s]
# Copying files: 65 files [00:02, 27.40 files/s]
# Copying files: 70 files [00:02, 32.60 files/s]
# Copying files: 74 files [00:03, 34.14 files/s]
# ...

# %%
import splitfolders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.

splitfolders.ratio("/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Moderate Damages",
                   output="/content/drive/MyDrive/RenamedDataset3/test",seed=1330, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  5.75 files/s]
# Copying files: 3 files [00:00,  6.57 files/s]
# Copying files: 5 files [00:00, 10.00 files/s]
# Copying files: 10 files [00:00, 20.13 files/s]
# Copying files: 14 files [00:00, 25.48 files/s]
# Copying files: 18 files [00:01, 21.97 files/s]
# Copying files: 22 files [00:01, 25.06 files/s]
# Copying files: 26 files [00:01, 27.55 files/s]
# Copying files: 30 files [00:01, 28.60 files/s]
# Copying files: 36 files [00:01, 35.63 files/s]
# Copying files: 40 files [00:01, 31.75 files/s]
# Copying files: 44 files [00:01, 32.93 files/s]
# Copying files: 49 files [00:01, 36.72 files/s]
# Copying files: 53 files [00:01, 37.05 files/s]
# Copying files: 60 files [00:02, 43.01 files/s]
# Copying files: 65 files [00:02, 42.15 files/s]
# Copying files: 71 files [00:02, 46.62 files/s]
# Copying files: 76 files [00:02, 45.22 files/s]
# Copying files: 81 files [00:02, 43.52 files/s]
# ...

# %%
import splitfolders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.

splitfolders.ratio("/content/drive/MyDrive/RenamedDataset3/Renamed/damged/Severe Damages",
                   output="/content/drive/MyDrive/RenamedDataset3/test",seed=1330, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 5 files [00:00, 36.96 files/s]
# Copying files: 12 files [00:00, 52.41 files/s]
# Copying files: 18 files [00:00, 53.24 files/s]
# Copying files: 24 files [00:00, 47.03 files/s]
# Copying files: 29 files [00:00, 45.40 files/s]
# Copying files: 35 files [00:00, 49.19 files/s]
# Copying files: 41 files [00:00, 45.28 files/s]
# Copying files: 47 files [00:00, 47.06 files/s]
# Copying files: 52 files [00:01, 35.82 files/s]
# Copying files: 58 files [00:01, 40.94 files/s]
# Copying files: 64 files [00:01, 39.89 files/s]
# Copying files: 70 files [00:01, 43.56 files/s]
# Copying files: 75 files [00:01, 44.83 files/s]
# Copying files: 84 files [00:01, 45.31 files/s]

# %%
import tensorflow as tf
import os

data_dir = "/content/drive/MyDrive/RenamedDataset3/test"
subdirs = os.listdir(data_dir)

for subdir in subdirs:
    subdir_path = os.path.join(data_dir, subdir)
    if os.path.isdir(subdir_path):
        count = len(os.listdir(subdir_path))
        print("Subfolder:", subdir, "Image count:", count)
# Out:
# Subfolder: train Image count: 6
# Subfolder: val Image count: 6
# Subfolder: test Image count: 6

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define paths to your dataset
train_data_dir = '/content/drive/MyDrive/RenamedDataset3/Renamed/test/train'
validation_data_dir = '/content/drive/MyDrive/RenamedDataset3/Renamed/test/val/headlight (minor)'
test_data_dir = '/content/drive/MyDrive/RenamedDataset3/Renamed/test/test'

# Define image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 32

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

# Model Architecture
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(12, activation='softmax')  # Update number of output classes to 12
])


# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=20,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size)

# Evaluation
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

evaluation = model.evaluate(test_generator)

print("Test Accuracy:", evaluation[1])

# Prediction
# Use the trained model to predict on new images
# Example:
# new_images = load_images('path/to/new_images')
# predictions = model.predict(new_images)
# Process predictions to interpret results

# %%
import splitfolders

splitfolders.ratio("/content/drive/MyDrive/RenamedDataset3/Renamed/newDATA",
                   output="/content/drive/MyDrive/RenamedDataset3/Renamed/split",seed=1330, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 3 files [00:00, 26.39 files/s]
# Copying files: 6 files [00:00, 20.95 files/s]
# Copying files: 14 files [00:00, 41.73 files/s]
# Copying files: 19 files [00:00, 43.80 files/s]
# Copying files: 24 files [00:00, 43.29 files/s]
# Copying files: 29 files [00:00, 44.26 files/s]
# Copying files: 36 files [00:00, 50.37 files/s]
# Copying files: 42 files [00:00, 48.90 files/s]
# Copying files: 48 files [00:01, 51.27 files/s]
# Copying files: 54 files [00:01, 40.68 files/s]
# Copying files: 60 files [00:01, 44.21 files/s]
# Copying files: 65 files [00:01, 40.72 files/s]
# Copying files: 71 files [00:01, 43.46 files/s]
# Copying files: 77 files [00:01, 45.37 files/s]
# Copying files: 84 files [00:01, 50.67 files/s]
# Copying files: 90 files [00:02, 32.55 files/s]
# Copying files: 95 files [00:02, 34.66 files/s]
# Copying files: 101 files [00:02, 39.56 files/s]
# Copying files: 106 files [00:02, 35.87 files/s]
# ...

# %%
data_training_path = "/content/drive/MyDrive/RenamedDataset3/Renamed/split/train"
data_testing_path = "/content/drive/MyDrive/RenamedDataset3/Renamed/split/test"
data_validating_path = "/content/drive/MyDrive/RenamedDataset3/Renamed/split/val"

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_training_path,
    shuffle=True,
    image_size = (img_width,img_height),
    batch_size = 32,
    validation_split = False
)
# Out:
# Found 228 files belonging to 4 classes.

# %%
data_cat = data_train.class_names
data_cat
# Out:
# ['headlight (minor)',
#  'headlight (moderate)',
#  'headlight (severe)',
#  'undamged_headlight ']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_validating_path,
                                                       image_size=(img_width, img_height),
                                                       batch_size=32,
                                                       shuffle=False,
                                                       validation_split=False)
# Out:
# Found 75 files belonging to 4 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(data_testing_path,
                                                       image_size=(img_width, img_height),
                                                       batch_size=32,
                                                       shuffle=False,
                                                       validation_split=False)
# Out:
# Found 78 files belonging to 4 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation ='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
    ])

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 19s 1s/step - loss: 3.6123 - accuracy: 0.2588 - val_loss: 1.4831 - val_accuracy: 0.2133
# Epoch 2/25
# 8/8 [==============================] - 27s 3s/step - loss: 1.3641 - accuracy: 0.3026 - val_loss: 1.3672 - val_accuracy: 0.3067
# Epoch 3/25
# 8/8 [==============================] - 24s 2s/step - loss: 1.2630 - accuracy: 0.4035 - val_loss: 1.2566 - val_accuracy: 0.4533
# Epoch 4/25
# 8/8 [==============================] - 19s 2s/step - loss: 1.1243 - accuracy: 0.5307 - val_loss: 1.2389 - val_accuracy: 0.4533
# Epoch 5/25
# 8/8 [==============================] - 16s 1s/step - loss: 0.9933 - accuracy: 0.6140 - val_loss: 1.2488 - val_accuracy: 0.4533
# Epoch 6/25
# 8/8 [==============================] - 16s 1s/step - loss: 0.8414 - accuracy: 0.6930 - val_loss: 1.3165 - val_accuracy: 0.4400
# Epoch 7/25
# 8/8 [==============================] - 16s 1s/step - loss: 0.7459 - accuracy: 0.7149 - val_loss: 1.3418 - val_accuracy: 0.4800
# ...

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'], label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'], label = 'Training loss')
plt.plot(epochs_range, history.history['val_loss'], label = 'Validation loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = "/content/drive/MyDrive/RenamedDataset3/Renamed/newDATA/headlight (moderate)/Headlight(moderate)_13.png"

image = tf.keras.utils.load_img(image, target_size=(img_height, img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat = tf.expand_dims(img_arr, 0)

# %%
predict = model.predict(img_bat)

score = tf.nn.softmax(predict)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
print('Car damage is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Car damage is headlight (severe) with accuracy of 48.27

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Load and preprocess the image
image_path = "/content/drive/MyDrive/RenamedDataset3/Renamed/newDATA/headlight (moderate)/Headlight(moderate)_13.png"
img = image.load_img(image_path, target_size=(img_height, img_width))
img_array = image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
img_array = img_array / 255.0  # Normalize pixel values

# Make predictions
predictions = model.predict(img_array)
predicted_class = data_cat[np.argmax(predictions)]
confidence = np.max(predictions) * 100

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# Print the actual and predicted outputs with confidence level
print(f"Actual Output: Damaged")
print(f"Predicted Output: {predicted_class} (Confidence: {confidence:.2f}%)")
# Out:
# 1/1 [==============================] - 0s 54ms/step
# Actual Output: Damaged
# Predicted Output: undamged_headlight  (Confidence: 1882.79%)
